# %% [markdown]
# Function is a block of code that performs a speecfic task. Functions help in organizing code , reusing code , and improving readability.

# %%
# def function_name(parametres):
#     """Docstring"""
#     # Function body
#     return expression

# %%
num = 24
if num%2==0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# The number is even

# %%
def evenFunction(num):
    if(num%2==0):
        print("Given Number is Even")
    else:
        print("Given Number is Odd")

 
evenFunction(4)
# Out:
# Given Number is Even

# %%
## Function with multiple parameters
def add(a,b):
    return a+b

print(add(3,4))
# Out:
# 7

# %%
def greet(name):
    print(f"Hello {name}")

greet("Muskan")
# Out:
# Hello Muskan

# %%
### Variable Lenghth Argument 
### Position and Keywords argumrts

def print_number(*args):
    for number in args:
        print(number)

print_number(1,2,3,4,5,6,7,9,"Hello")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 9
# Hello

# %%
## Keysword Arguments

def print_details(*agrs, **kwargs):
 for val in agrs:
    print(f"Postional argument : {val}")

 for key,value in kwargs.items():
        print(f"{key}:{value}")


print_details(1,2,3,4,5,name="Muskan", age=90 , last_name="Chauhan")
# Out:
# Postional argument : 1
# Postional argument : 2
# Postional argument : 3
# Postional argument : 4
# Postional argument : 5
# name:Muskan
# age:90
# last_name:Chauhan

# %%
def multiply(a,b):
    return a*b,a,b


multiply(7,8)
# Out:
# (56, 7, 8)
