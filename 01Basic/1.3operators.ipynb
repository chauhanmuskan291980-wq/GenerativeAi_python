# %%
## if statement 
age =  18
if age>=18:
    print("You are allowed to vote in the elections")
# Out:
# You are allowed to vote in the elections

# %%
## else
## he else statement exectues a block of code , if the condition in the if statement is False.

age = 16

if age>=18:
    print("You are eligible for voting")
else:
    print("You are a minor")
# Out:
# You are a minor

# %%
## elif
## The elif statement allows you to check multiple conditions. It stands for "else-if"

age = 20

if age<13:
    print("You are a child......")
elif age<18:
    print("You are a teenager.......")
else:
    print("You are an adult......")
# Out:
# You are an adult......

# %%
## Nested Conditional Statements
# You can place one or more if , elif or else statements inside another if , elif or else statement to create nested conditional statements.
## number even , odd and negitive

num = int(input("Enter Your Number"))

if num>=0:
    print("The number is positive")
    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")

else:
    print("Give number is zero or negitive")
# Out:
# Give number is negitive

# %%
## Use Case:
## Determine if a year is leap year using nested condition statement 

year = int(input("Enter the year: "))

if (year % 4 == 0):
    if (year % 100 == 0):
        if (year % 400 == 0):
            print(year, "is a Leap Year")
        else:
            print(year, "is not a Leap Year")
    else:
        print(year, "is a Leap Year")
else:
    print(year, "is not a Leap Year")
# Out:
# 2012 is a Leap Year

# %%
## Assignment 
## Simple Calculater 

num1 = float(input("Enter First number: "))
num2 = float(input("Enter second number: "))
operation = input("enter operation(+,-,*,/): ")

if operation == '+':
    result = num1+num2
elif operation == '-':
    result = num1-num2
elif operation == '*':
     result = num1*num2
elif operation == '/':
     if num2!=0:
          result = num1/num2
     else:
          result="Error ! Division by zero"
else:
     result = "invaild operation"

print("result: ",result)
# Out:
# result:  invaild operation

# %%
### Determine the ticket price baed on age and whether the person is a student.

age = int(input("Enter your age: "))
is_student = input("Are you a student ? (yes/no): ").lower()

if(age<5):
    price = "free"
elif(age <=12):
    price= '$10'

elif(age<=17):
    if is_student == 'yes':
         price = '$12'
    else:
        price= '$20'
else:
    price = '$25'

print("Price of your ticket" , price)
# Out:
# Price of your ticket $20
