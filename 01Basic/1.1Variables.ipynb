# %% [markdown]
# Variable are fundamental elements in programming used to store data that can be referenced and manipluated in program . In python , variables are created when you assign a value of them , and they do not need explicit decaration  to reserve memory space . The declaration happens automatically when you assign a value to a variable.

# %%
a=100

# %%
## Declaring and assigning Variables

age=32
height=6.1
name="Muskan"
is_student= True

## printing the variable 
print("age: ",age)
print("height" , height)
print("Name: ", name)
# Out:
# age:  32
# height 6.1
# Name:  Muskan

# %%
## Naming Convertions
## variable names should be descrpitive
## They must start with a letter or an '_' and contain letter , numbers and under scroes
## variables name case sensitive 
# valid variable name
fisrt_name = "Muskan"
lats_name = "Chauhan"

##Inavild variable name
# 2age =  3
# fisrt-name= "Muskan"
# @naem= "Muskan"
## understanding Variable types
## Python is dynamically typed , type of a variable is detemine at runtime
age = 22    # int
height = 6.1   #float
name = "Muskan"   #str
is_student = True  #Bool

# %%
## Type Checking and Conversion 
age= 25
print(type(age))
age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
## Dynamic Typeing 
var = 10 
print(var , type(var))
var = "Hello"
print(type(var))

var = 12.3
print(type(var))


age = int(input("What is the age"))
print(age , type(age))
# Out:
# 10 <class 'int'>
# <class 'str'>
# <class 'float'>
# 7 <class 'int'>

# %%
num1 = float(input("Enetr your first number: "))
num2 = float(input("Enetr your second number: "))

sum = num1+num2
difference = num1-num2
product = num1*num2
quotient = num1/num2
print("Sum: ", sum)
print("Difference: ", difference)
print("Product: ", product)
print("Quotient: ",quotient)
# Out:
# Sum:  16.0
# Difference:  -2.0
# Product:  63.0
# Quotient:  0.7777777777777778
