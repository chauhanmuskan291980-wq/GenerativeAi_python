# %% [markdown]
# ### Semantics refers to the meaning or the interpretation of the symbol, characters and commands in a language. It is about what the code is supposed to do when ot runs .

# %% [markdown]
# ### sytax refers to the set of the rules that defines the combinations of symbol that are considered to be correctly structured programs in a language . In simpler terms, sytax is about tje correct arrangement of the words and symbol in a code.

# %%
## Basic Syntax Rules In Pythons
## Case sensitivity - Python is case sensitive

name = "Muskan"
Name = "Chauhan"
print(name)
print(Name)
# Out:
# Muskan
# Chauhan

# %% [markdown]
# Indentation in python is used to define the structure and hierarchy of the code , Unlike many other programming language that use braces {} to delimit blocks of code , Python uses indentation to determine the grouping of statements . This means that all the statements within a block must be indented at the same level

# %%
## Indentation
## Python uses indentation blocks of code , Consistent use of sppaces (commonly 4) or a tab  is required

age = 32
if age < 30:
    print(age)

print(age)
# Out:
# 32

# %%
## This is a single line comment
print("Hello World")
# Out:
# Hello World

# %%
## Line Continuation
total = 1+2+3+4+5+6+7 + \
9+0
print(total)
# Out:
# 37

# %%
## Multiple Statement on a single line
x=5; y=10; z=x+y
print(z)
# Out:
# 15

# %%
##Understand Semnatics In Python
## Variable assignmnet
age = 32  ## age is an integer
name = "Muskan" ## Naem is string
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
##Type Inference
variable=10
print(type(variable))
variable="Muskan"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=32
if age>30:
 print(age)
# Out:
# 32

# %%
if True:
    print("Correct Indentation")
    if False:
        print("This ont print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block
