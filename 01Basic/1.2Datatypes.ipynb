# %% [markdown]
# Datatype are classification of data which tell the complier or interpreter how the programmer intends to use the data.
# They dtermine the type of operations that can be performed on the data , the vlaues that the data can take and the amount of the memory needed to store the data.

# %%
##Interger expamle 

age = 34
type(age)
print(type(age))
# Out:
# <class 'int'>

# %%
## String
name = "Muskan" 
print(type(name))
# Out:
# <class 'str'>

# %%
is_true = True
type(is_true)
a=12
b=12
print(type(a==b))
# Out:
# <class 'bool'>

# %%
## Common error's
result = "Hello" + str(5)
print(result)
# Out:
# Hello5
