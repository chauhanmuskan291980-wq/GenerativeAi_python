# %%
# Exception handling in python allows you to handle wrrors gracefully and take crrective actions without stopping the excetion of the program
# the lession will cover the basic of execption including how ti use the try except else and finally blocks.

# %%
## Exception try , except block

try:
    a=b 
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
   result = 1/0
except ZeroDivisionError as error:
   print(error)
   print("please ebter the denominator greater than 0...")
# Out:
# division by zero
# please ebter the denominator greater than 0

# %%
try:
   result = 1/4
   print(a/b)
except ZeroDivisionError as error:
   print(error)
   print("please ebter the denominator greater than 0...")
except Exception as ex1:
   print(ex1)
   print("Main exception got caught here")
# Out:
# name 'a' is not defined
# Main exception got caught here

# %%
try:
    num = int(input("Enter a number"))
    result= 10/num
    print(result)
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("enter denominator grater than 0")
except Exception as ex:
    print(ex)
else:
    print(f"The result is {result}")
# Out:
# enter denominator grater than 0

# %%
try:
    num = int(input("Enter a number"))
    result= 10/num
    print(result)
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("enter denominator grater than 0")
except Exception as ex:
    print(ex)
else:
    print(f"The result is {result}")
finally:
    print("Excetion complete.")
# Out:
# 2.0
# The result is 2.0
# Excetion complete.

# %%
try:
    file = open('example.txt1','r')
    content = file.read()
    print(content)

except FileNotFoundError:
    print("The file does not exits")
except Exception as ex:
    print(ex)

finally:
    if 'file' in locals() or not file.close():
        file.close()
        print('file close')
# Out:
# The file does not exits
# file close
