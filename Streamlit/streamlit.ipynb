# %% [markdown]
# Streamlit in an open source app framework fo machine Learning and data science projects.Its allows you to create beautiful web applications for you machine learning and data science projects with simple Python scripts.
