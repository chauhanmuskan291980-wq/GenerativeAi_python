# %%
import os
cwd = os.getcwd()
print(f"Current working directory is {cwd}")
# Out:
# Current working directory is e:\GenerativeAi_python\file_Handling

# %%
new_dirctory = "package"
os.mkdir(new_dirctory)
print(f"Directory '{new_dirctory}'")
# Out:
# Directory 'package'

# %%
### Listing files and Dirctories
items = os.listdir('.')
print(items)
# Out:
# ['destination.txt', 'example.bin', 'example.txt', 'fileoperation.ipynb', 'filepath.ipynb', 'package']

# %%
### Joing Paths

dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# e:\GenerativeAi_python\file_Handling\folder\file.txt

# %%
path = 'example.txt'
if os.path.exists(path):
    print(f"The path '{path}' exits")
else:
    print(f"The path '{path}' does not exits")
# Out:
# The path 'example.txt' exits

# %%
## Checking the file is avaiable or not
import os

path = 'example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is nethier a file nor a dirctory.")
# Out:
# The path 'example.txt' is a file.

# %%
## Getting a absolute path 

relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# e:\GenerativeAi_python\file_Handling\example.txt
