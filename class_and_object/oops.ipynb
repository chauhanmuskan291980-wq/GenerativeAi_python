# %% [markdown]
# Object-Orirnted programming(OOP) is a programming paradigm rgar uses "Objects" to design applications and computer programs. OOP allows for modeling real-world scenarios using classes

# %%
### A class in a blue print for creating objects , Attributes , methods
class Car:
    pass

audi = Car()
bmw=Car()
print(type(audi))
print(audi)

audi.windows = 4
print(audi.windows)
# Out:
# <class '__main__.Car'>
# ...
# 4

# %%
## Instance Variable and Methods 

tata = Car()
tata.doors = 4
print(tata.doors)
dir(tata)
# Out:
# 4
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
## Instance Variable and Methods

class Dog:
    ## Construtor
    def __init__(self,name,age):
        self.name=name
        self.age= age

## create the objects
dog1 = Dog("Buddy",3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Buddy
# 3

# %%
dog2 = Dog("Lucy",11)
print(dog2)
print(dog2.name)
print(dog1.age)
# Out:
# ...
# Lucy
# 3

# %%
## Defibe a class with instance methods
class Dog:
    def __init__(self,name,age):
        self.name= name
        self.age=age
    
    def bark(self):
        print(f"{self.name} says woof")

dog1 = Dog("Buddy",3)
dog1.bark()
dog2 = Dog("Lucy",4)
dog2.bark()
# Out:
# Buddy says woof
# Lucy says woof

# %%
### Modeling A Bank Account

## Define a class for bank account

class BankAccount:
    def __init__(self,owner,balance):
        self.owner= owner
        self.balance= balance
    
    def deposit(self,amount):
        self.balance+= amount
        print(f"{amount} is deposited , New balance is {self.balance}")

    def withdraw(self,amount):
        if(amount>self.balance):
            print("Insuffecient Funds!")
        else:
            self.balance-=amount
            print(f"{amount} is withdraw , New Balance is {self.balance}")

    def get_balance(self):
        return self.balance
    

account = BankAccount("Muskan",1200)
print(account.balance)


account.deposit(100)
account.withdraw(300)
print(account.get_balance())
# Out:
# 1200
# 100 is deposited , New balance is 1300
# 300 is withdraw , New Balance is 1000
# 1000

# %% [markdown]
# Conclusion
# Object-Orintend Programming(OOP) allows you to model real-world scenarios using classes and objects , define instance variables and methods and use themm to perform various operations. Undertanding thses concept is fundamental to wrtting effective and maintable python code
