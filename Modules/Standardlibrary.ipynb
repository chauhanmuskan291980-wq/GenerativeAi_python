# %% [markdown]
# Python's standard libary is vast ccollection of modules and packeages that comes bundleed with python, providing a wide range of functionalities out of the bpx. Here's an overview of same of the most commonly used modules and packages in the python standard library.

# %%
import array
arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math  
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 2
# cherry

# %%
# File and Directory Access
import os
print(os.getcwd())
# Out:
# e:\GenerativeAi_python\Modules

# %%
os.mkdir('test_dir')

# %%
# high level operations on files and collection of files

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization

import json
data = {'name':'Krish' , 'age':25}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Krish", "age": 25}
# <class 'str'>
# {'name': 'Krish', 'age': 25}
# <class 'dict'>

# %%
## CSV

import csv 
with open('exapmle.csv',mode= 'w',newline='') as file:
    writer= csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Muskan',23])

with open('exapmle.csv',mode= 'r',newline='') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Muskan', '23']

# %%
## Datetime
from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-04-22 17:54:33.856158
# 2026-04-21 17:54:33.856158

# %%
## time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1776860729.4990125
# 1776860731.5040517

# %%
## regular expression

import re

pattern =r'\d+'
text = "There are 123 apples and 45 mangos"
match = re.search(pattern,text)
print(match.group())
# Out:
# 123
